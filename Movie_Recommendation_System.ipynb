# %% [markdown]
# <a href="https://colab.research.google.com/github/debasishpohi1999/seeds.csv-df-/blob/main/Movie_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Report: Movie Recommendation System**
# ## **Introduction**
# The "Movie Recommendation System" project aims to analyze a dataset of movies and user ratings to derive insights and create visualizations. The goal is to understand the trends in movie ratings and develop a recommendation system based on user preferences and movie genres.
#
# ## **Data Sources**
# Two primary datasets were used:
# 1.	Movies Dataset: Contains movie IDs, titles, and genres.
# 2.	Ratings Dataset: Contains user IDs, movie IDs, ratings, and timestamps.
#
# ## **Libraries Used**
# •	Pandas: For data manipulation and analysis.
#
# •	Matplotlib: For creating visualizations.
#
# •	WordCloud: For generating word cloud visualizations.
#
# •	scikit-learn: For feature extraction and similarity calculations.
#
#
# ## **Data Loading and Exploration**
# The datasets were loaded and explored using Pandas. This involved displaying information about the datasets to understand their structure and content. The shapes of the datasets were checked to understand their size, and descriptive statistics were generated to summarize the data.
#
# ## **Data Visualization**
#
# # Word Cloud for Genres and Titles
# Unique genres and movie titles were extracted from the movies dataset to create word clouds. The genres were combined into a single string, and the movie titles were processed to remove the release year.
#
# Word clouds were then generated for both genres and movie titles. The word cloud for genres highlighted the most common genres in the dataset, while the word cloud for movie titles showed the diversity of movie titles.
# Merging Datasets
#
# The movies and ratings datasets were merged on the movieId column to create a combined dataset. This allowed for the aggregation and visualization of ratings data.
#
# ## **Aggregation and Visualization of Ratings**
# # Highest Rated Movies
# The sum of ratings for each movie was calculated to identify the highest-rated movies. A bar chart was created to visualize the top 20 highest-rated movies, highlighting those with the most cumulative ratings.
#
# # Most Rated Movies
# The count of ratings for each movie was calculated to find the most rated movies. Another bar chart was created to visualize the top 20 most rated movies, showing those with the highest number of ratings.
#
# ## **Content-Based Recommendation**
# # Vectorizing Genres
# A TF-IDF vectorizer was used to convert the genres into a matrix of TF-IDF features.
# This matrix was used to measure the similarity between movies based on their genres.
#
# # User-Movie Ratings Pivot Table
# A pivot table was created to represent user ratings for movies. This table facilitated the development of a recommendation system by organizing the data in a user-friendly format.
#
# ## **Conclusion**
# This project successfully analyzed the movies and ratings datasets, providing insightful visualizations and data summaries. The steps included loading the data, exploring and visualizing the data, and creating a pivot table for user-movie ratings. Future work includes developing a recommendation system using collaborative filtering or content-based filtering techniques based on the insights derived.
#
# ## **Future Work**
# •	Implement collaborative filtering using user-item interaction data.
#
# •	Develop a recommendation engine that combines both content-based and collaborative filtering methods.
#
# •	Explore time-based patterns in movie ratings to enhance recommendation accuracy.
#
#
# ## **References**
# • Movies dataset:
#
# •	Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B., Grisel, O., ... & Vanderplas, J. (2011). Scikit-learn: Machine Learning in Python. Journal of Machine Learning Research, 12, 2825-2830.
#
# •	Hunter, J. D. (2007). Matplotlib: A 2D Graphics Environment. Computing in Science & Engineering, 9(3), 90-95.
#
# •	Mueller, A. C., & Guido, S. (2016). Introduction to Machine Learning with Python: A Guide for Data Scientists. O'Reilly Media, Inc.
#
# •	WordCloud Documentation. Retrieved from WordCloud GitHub

# %%
#Importing libraries

import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
#Loading data files

movies=pd.read_csv('/content/movies.csv')
ratings=pd.read_csv('/content/ratings.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10329 entries, 0 to 10328
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  10329 non-null  int64
#  1   title    10329 non-null  object
#  2   genres   10329 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 242.2+ KB

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105339 entries, 0 to 105338
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     105339 non-null  int64
#  1   movieId    105339 non-null  int64
#  2   rating     105339 non-null  float64
#  3   timestamp  105339 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.2 MB

# %%
movies.shape
# Out:
# (10329, 3)

# %%
ratings.shape
# Out:
# (105339, 4)

# %%
movies.describe()
# Out:
#              movieId
# count   10329.000000
# mean    31924.282893
# std     37734.741149
# min         1.000000
# 25%      3240.000000
# 50%      7088.000000
# 75%     59900.000000
# max    149532.000000

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  105339.000000  105339.000000  105339.000000  1.053390e+05
# mean      364.924539   13381.312477       3.516850  1.130424e+09
# std       197.486905   26170.456869       1.044872  1.802660e+08
# min         1.000000       1.000000       0.500000  8.285650e+08
# 25%       192.000000    1073.000000       3.000000  9.711008e+08
# 50%       383.000000    2497.000000       3.500000  1.115154e+09
# 75%       557.000000    5991.000000       4.000000  1.275496e+09
# max       668.000000  149532.000000       5.000000  1.452405e+09

# %%
genres=[]
for genre in movies.genres:

    x=genre.split('|')
    for i in x:
         if i not in genres:
            genres.append(str(i))
genres=str(genres)
movie_title=[]
for title in movies.title:
    movie_title.append(title[0:-7])
movie_title=str(movie_title)

# %%
#Data Visualization
wordcloud_genre=WordCloud(width=1500,height=800,background_color='black',min_font_size=2
                    ,min_word_length=3).generate(genres)
wordcloud_title=WordCloud(width=1500,height=800,background_color='cyan',min_font_size=2
                    ,min_word_length=3).generate(movie_title)
plt.figure(figsize=(30,10))
plt.axis('off')
plt.title('WORDCLOUD for Movies Genre',fontsize=30)
plt.imshow(wordcloud_genre)

# %%
plt.figure(figsize=(30,10))
plt.axis('off')
plt.title('WORDCLOUD for Movies title',fontsize=30)
plt.imshow(wordcloud_title)

# %%
df=pd.merge(ratings,movies, how='left',on='movieId')
df.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       16     4.0  1217897793
# 1       1       24     1.5  1217895807
# 2       1       32     4.0  1217896246
# 3       1       47     4.0  1217896556
# 4       1       50     4.0  1217896523
#
#                                        title                   genres
# 0                              Casino (1995)              Crime|Drama
# 1                              Powder (1995)             Drama|Sci-Fi
# 2  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 3                Seven (a.k.a. Se7en) (1995)         Mystery|Thriller
# 4                 Usual Suspects, The (1995)   Crime|Mystery|Thriller

# %%
df1=df.groupby(['title'])[['rating']].sum()
high_rated=df1.nlargest(20,'rating')
high_rated.head()
# Out:
#                                            rating
# title
# Shawshank Redemption, The (1994)           1372.0
# Pulp Fiction (1994)                        1352.0
# Forrest Gump (1994)                        1287.0
# Silence of the Lambs, The (1991)           1216.5
# Star Wars: Episode IV - A New Hope (1977)  1143.5

# %%
plt.figure(figsize=(10,5))
plt.title('Top 20 movies with highest rating',fontsize=20)
colors=['red','yellow','orange','green','magenta','cyan','blue','lightgreen','skyblue','purple']
plt.ylabel('ratings',fontsize=10)
plt.xticks(fontsize=10,rotation=90)
plt.xlabel('movies title',fontsize=20)
plt.yticks(fontsize=15)
plt.bar(high_rated.index,high_rated['rating'],linewidth=3,edgecolor='red',color=colors)
# Out:
# <BarContainer object of 20 artists>

# %%
df2=df.groupby('title')[['rating']].count()
rating_count_20=df2.nlargest(20,'rating')
rating_count_20.head()
# Out:
#                                   rating
# title
# Pulp Fiction (1994)                  325
# Forrest Gump (1994)                  311
# Shawshank Redemption, The (1994)     308
# Jurassic Park (1993)                 294
# Silence of the Lambs, The (1991)     290

# %%
plt.figure(figsize=(10,5))
plt.title('Top 20 movies with highest number of ratings',fontsize=20)
plt.xticks(fontsize=10,rotation=90)
plt.yticks(fontsize=10)
plt.xlabel('movies title',fontsize=20)
plt.ylabel('ratings',fontsize=20)

plt.bar(rating_count_20.index,rating_count_20.rating,color='red')
# Out:
# <BarContainer object of 20 artists>

# %%
cv=TfidfVectorizer()
tfidf_matrix=cv.fit_transform(movies['genres'])
movie_user = df.pivot_table(index='userId',columns='title',values='rating')
movie_user.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Til There Was You (1997)  'burbs, The (1989)  \
# userId
# 1                          NaN                        NaN                 NaN
# 2                          NaN                        NaN                 NaN
# 3                          NaN                        NaN                 NaN
# 4                          NaN                        NaN                 NaN
# 5                          NaN                        NaN                 NaN
#
# title   'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# ...

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
indices=pd.Series(movies.index,index=movies['title'])
titles=movies['title']
def recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:21]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]
recommendations('Toy Story (1995)')
# Out:
# 1815                                           Antz (1998)
# 2496                                    Toy Story 2 (1999)
# 2967        Adventures of Rocky and Bullwinkle, The (2000)
# 3166                      Emperor's New Groove, The (2000)
# 3811                                 Monsters, Inc. (2001)
# 6617     DuckTales: The Movie - Treasure of the Lost La...
# 6997                                      Wild, The (2006)
# 7382                                Shrek the Third (2007)
# 7987                        Tale of Despereaux, The (2008)
# 9215     Asterix and the Vikings (Astérix et les Viking...
# 9732                                          Turbo (2013)
# 10052                                Boxtrolls, The (2014)
# 1595                            Black Cauldron, The (1985)
# 1675                         Lord of the Rings, The (1978)
# 2696                 We're Back! A Dinosaur's Story (1993)
# 3420                      Atlantis: The Lost Empire (2001)
# ...
